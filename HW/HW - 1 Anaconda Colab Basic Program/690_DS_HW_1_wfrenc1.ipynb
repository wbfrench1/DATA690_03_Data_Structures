# %%
s_name = (input('Please enter your name: '))

while True:
  try:
    i_num = int(input('Please enter an integer: '))
    break
  except:
    print('That was not an integer.  Please enter an integer.')


while i_num != 0:
  print(s_name)
  i_num -= 1
# Out:
# Please enter your name: Barker French
# Please enter an integer: 10
# Barker French
# Barker French
# Barker French
# Barker French
# Barker French
# Barker French
# Barker French
# Barker French
# Barker French
# Barker French
